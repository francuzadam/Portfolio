# %% [markdown]
# Data Transformation to Visualize

# %% [markdown]
# Import the required libraries

# %%
import pandas as pd
from datetime import datetime

# %% [markdown]
# Import the dataset and transform

# %%
football_data = pd.read_csv("2021-2022.csv")
football_data["Date"] = pd.to_datetime(football_data["Date"], format='%d/%m/%Y')
football_data["Year"] = football_data["Date"].dt.year
football_data["MonthNum"] = football_data["Date"].dt.month
football_data['Month'] = football_data['Date'].dt.strftime('%B')
football_data["Day"] = football_data["Date"].dt.day
football_data["Result"] = football_data["FTHG"].astype(str) + " - " + football_data["FTAG"].astype(str)
football_data.reset_index(inplace=True)
football_data.head()
# Out:
#    index Div       Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  \
# 0      0  E0 2021-08-13  20:00   Brentford         Arsenal     2     0   H
# 1      1  E0 2021-08-14  12:30  Man United           Leeds     5     1   H
# 2      2  E0 2021-08-14  15:00     Burnley        Brighton     1     2   A
# 3      3  E0 2021-08-14  15:00     Chelsea  Crystal Palace     3     0   H
# 4      4  E0 2021-08-14  15:00     Everton     Southampton     3     1   H
#
#    HTHG  ...  PCAHA MaxCAHH MaxCAHA  AvgCAHH  AvgCAHA  Year  MonthNum   Month  \
# 0     1  ...   2.13    2.05    2.17     1.80     2.09  2021         8  August
# 1     1  ...   1.77    2.19    1.93     2.10     1.79  2021         8  August
# 2     1  ...   2.14    1.82    2.19     1.79     2.12  2021         8  August
# 3     2  ...   1.81    2.16    1.93     2.06     1.82  2021         8  August
# 4     0  ...   1.88    2.08    1.90     2.03     1.86  2021         8  August
#
#    Day  Result
# 0   13   2 - 0
# ...

# %% [markdown]
# Export data

# %%
football_data.to_excel("input_excel.xlsx")
